# %%
from typing import Dict, List, Tuple, Union, Optional, Callable

import sys
import wandb
import numpy as np
import math
import pandas as pd
import os
from copy import deepcopy
from argparse import Namespace
from pathlib import Path
import logging
import torch
from scipy import stats
from torch.optim import Adam
from torch.utils.data import DataLoader as DL_torch
from torch_geometric.data import DataLoader
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from functools import partial
# import pdb

from abag_affinity.dataset import AffinityDataset
from abag_affinity.dataset.advanced_data_utils import complexes_from_dms_datasets, get_bucket_dataloader, load_datasets
from abag_affinity.model import AffinityGNN, TwinWrapper
from abag_affinity.train.wandb_config import configure
from abag_affinity.utils.config import get_data_paths, read_config
from abag_affinity.utils.visualize import plot_correlation
from abag_affinity.utils.argparse_utils import read_args_from_file, parse_args
from abag_affinity.train.utils import load_model
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
args_file = "base_args.txt"

sys.argv = sys.argv[:1]
args = parse_args(args_file=args_file)

config = read_config(args.config_file)

use_cuda = False
device = 'cpu'

train_data, val_datas = load_datasets(config, args.target_dataset, args.validation_set, args)
model = load_model(train_data.num_features, train_data.num_edge_features, args.target_dataset, args, device)

# wandb_benchmark_log = run_and_log_benchmarks(model, args, wandb_inst)
# Out:
# distances [[ 0.         1.3289889  4.215144  ... 22.726692  27.211779  26.307308 ]
#  [ 1.3289889  0.         1.3291218 ... 26.047619  30.372355  29.624786 ]
#  [ 4.215144   1.3291218  0.        ... 28.800217  33.1427    31.846134 ]
#  ...
#  [22.726692  26.047619  28.800217  ...  0.         1.329646   3.0448327]
#  [27.211779  30.372355  33.1427    ...  1.329646   0.         1.3290124]
#  [26.307308  29.624786  31.846134  ...  3.0448327  1.3290124  0.       ]]
# closes_noedes []
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [13], in <cell line: 11>()
#       8 use_cuda = False
#       9 device = 'cpu'
# ---> 11 train_data, val_datas = load_datasets(config, args.target_dataset, args.validation_set, args)
#      12 model = load_model(train_data.num_features, train_data.num_edge_features, args.target_dataset, args, device)
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/advanced_data_utils.py:299, in load_datasets(config, dataset, validation_set, args, validation_size, only_neglogkd_samples)
#     277 logger.debug(f"Get dataLoader for {dataset_name}#{loss_types}")
#     278 train_data = AffinityDataset(config, args.relaxed_pdbs, dataset_name, loss_types,
#     279                              train_ids,
#     280                              node_type=args.node_type,
#    (...)
#     296                              only_neglogkd_samples=only_neglogkd_samples,
#     297                              )
# --> 299 val_datas = [AffinityDataset(config, relaxed, dataset_name, loss_types,  # TODO @marco val should be done with the same loss as training, right?
#     300                              val_ids,
#     301                              node_type=args.node_type,
#     302                              max_nodes=args.max_num_nodes,
#     303                              interface_distance_cutoff=args.interface_distance_cutoff,
#     304                              interface_hull_size=args.interface_hull_size,
#     305                              max_edge_distance=args.max_edge_distance,
#     306                              pretrained_model=args.pretrained_model,
#     307                              scale_values=args.scale_values,
#     308                              scale_min=args.scale_min,
#     309                              scale_max=args.scale_max,
#     310                              relative_data=relative_data,
#     311                              save_graphs=args.save_graphs,
#     312                              force_recomputation=args.force_recomputation,
#     313                              preprocess_data=args.preprocess_graph,
#     314                              preprocessed_to_scratch=args.preprocessed_to_scratch,
#     315                              num_threads=args.num_workers,
#     316                              load_embeddings=None if not args.embeddings_type else (args.embeddings_type, args.embeddings_path),
#     317                              only_neglogkd_samples=only_neglogkd_samples,
#     318                              )
#     319              for relaxed in [bool(args.relaxed_pdbs)]
#     320              ]  # TODO disabling , not args.relaxed_pdbs for now. Enable once we generated all relaxed data
#     322 return train_data, val_datas
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/advanced_data_utils.py:299, in <listcomp>(.0)
#     277 logger.debug(f"Get dataLoader for {dataset_name}#{loss_types}")
#     278 train_data = AffinityDataset(config, args.relaxed_pdbs, dataset_name, loss_types,
#     279                              train_ids,
#     280                              node_type=args.node_type,
#    (...)
#     296                              only_neglogkd_samples=only_neglogkd_samples,
#     297                              )
# --> 299 val_datas = [AffinityDataset(config, relaxed, dataset_name, loss_types,  # TODO @marco val should be done with the same loss as training, right?
#     300                              val_ids,
#     301                              node_type=args.node_type,
#     302                              max_nodes=args.max_num_nodes,
#     303                              interface_distance_cutoff=args.interface_distance_cutoff,
#     304                              interface_hull_size=args.interface_hull_size,
#     305                              max_edge_distance=args.max_edge_distance,
#     306                              pretrained_model=args.pretrained_model,
#     307                              scale_values=args.scale_values,
#     308                              scale_min=args.scale_min,
#     309                              scale_max=args.scale_max,
#     310                              relative_data=relative_data,
#     311                              save_graphs=args.save_graphs,
#     312                              force_recomputation=args.force_recomputation,
#     313                              preprocess_data=args.preprocess_graph,
#     314                              preprocessed_to_scratch=args.preprocessed_to_scratch,
#     315                              num_threads=args.num_workers,
#     316                              load_embeddings=None if not args.embeddings_type else (args.embeddings_type, args.embeddings_path),
#     317                              only_neglogkd_samples=only_neglogkd_samples,
#     318                              )
#     319              for relaxed in [bool(args.relaxed_pdbs)]
#     320              ]  # TODO disabling , not args.relaxed_pdbs for now. Enable once we generated all relaxed data
#     322 return train_data, val_datas
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/data_loader.py:166, in AffinityDataset.__init__(self, config, is_relaxed, dataset_name, loss_criterion, pdb_ids, node_type, max_nodes, interface_distance_cutoff, interface_hull_size, max_edge_distance, pretrained_model, scale_values, scale_min, scale_max, relative_data, save_graphs, force_recomputation, preprocess_data, preprocessed_to_scratch, num_threads, load_embeddings, only_neglogkd_samples)
#     164 if self.preprocess_data:
#     165     self.logger.debug(f"Preprocessing {node_type}-graphs")
# --> 166     self.preprocess(relaxed)
#     168 # Copy embeddings to fast scratch space
#     169 if preprocessed_to_scratch:
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/data_loader.py:348, in AffinityDataset.preprocess(self, relaxed)
#     328     """ Function to get graph dict and store to disc. Used to parallelize preprocessing
#     329
#     330     Args:
#    (...)
#     335         None
#     336     """
#     338     graph_dict = load_graph_dict(row, self.dataset_name, self.config, self.interface_dir,
#     339                                  node_type=self.node_type,
#     340                                  interface_distance_cutoff=self.interface_distance_cutoff,
#    (...)
#     346                                  relaxed=self.is_relaxed
#     347                                 )
# --> 348 submit_jobs(preload_graph_dict, graph_dicts2process, self.num_threads)
#     350 if self.pretrained_model == "DeepRefine":
#     351     self.logger.debug(
#     352         f"Preprocessing {len(deeprefine_graphs2process)} DeepRefine graphs with {self.num_threads} threads")
#
# File ~/miniconda3/envs/ag_binding_diffusion3/lib/python3.8/site-packages/parallel.py:63, in submit_jobs(function, inputs, num_threads)
#      61 else:
#      62     logging.info('Sequential Mode.')
# ---> 63     out = [function(*args) for args in inputs]
#      65 return out
#
# File ~/miniconda3/envs/ag_binding_diffusion3/lib/python3.8/site-packages/parallel.py:63, in <listcomp>(.0)
#      61 else:
#      62     logging.info('Sequential Mode.')
# ---> 63     out = [function(*args) for args in inputs]
#      65 return out
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/data_loader.py:338, in AffinityDataset.preprocess.<locals>.preload_graph_dict(row, out_path)
#     327 def preload_graph_dict(row: pd.Series, out_path: str):
#     328     """ Function to get graph dict and store to disc. Used to parallelize preprocessing
#     329
#     330     Args:
#    (...)
#     335         None
#     336     """
# --> 338     graph_dict = load_graph_dict(row, self.dataset_name, self.config, self.interface_dir,
#     339                                  node_type=self.node_type,
#     340                                  interface_distance_cutoff=self.interface_distance_cutoff,
#     341                                  interface_hull_size=self.interface_hull_size,
#     342                                  max_edge_distance=self.max_edge_distance,
#     343                                  affinity_type=self.affinity_type,
#     344                                  load_embeddings=self.load_embeddings,
#     345                                  save_path=out_path,
#     346                                  relaxed=self.is_relaxed
#     347                                 )
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/utils.py:191, in load_graph_dict(row, dataset_name, config, interface_folder, node_type, interface_distance_cutoff, interface_hull_size, max_edge_distance, affinity_type, load_embeddings, save_path, relaxed)
#     188 else:
#     189     embeddings = None
# --> 191 graph_dict = get_graph_dict(pdb_id, pdb_file_path, embeddings, node_type, neg_log_kd, e_value, distance_cutoff=max_edge_distance)
#     193 graph_dict.pop("atom_names", None)  # remove unnecessary information that takes lot of storage
#     194 assert len(graph_dict["node_features"]) == len(graph_dict["closest_residues"])
#
# File ~/Documents/workspace/ag_binding_affinity/src/abag_affinity/dataset/utils.py:100, in get_graph_dict(pdb_id, pdb_file_path, embeddings, node_type, neg_log_kd, e_value, distance_cutoff, ca_alpha_contact)
#      98 print('distances', distances)
#      99 print('closes_noedes', closest_nodes)
# --> 100 assert len(closest_nodes) == len(residue_infos), "Number of closest nodes does not match number of residues"
#     101 node_features = get_residue_encodings(residue_infos, structure_info)
#     103 if embeddings:  # I think we need to inject them so harshly here, to facilitate backpropagation later. An alternative would be to load the OF data closer to the model..
#
# AssertionError: Number of closest nodes does not match number of residues

# %%
args = parse_args(artifical_args={"args_file": 'base_args.txt'})

config = read_config(args.config_file)

use_cuda = False
device = 'cpu'

train_data, val_datas = load_datasets(config, args.target_dataset, args.validation_set, args)
model = load_model(train_data.num_features, train_data.num_edge_features, args.target_dataset, args, device)
